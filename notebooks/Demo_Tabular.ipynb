# %%
import sys
import os

# Check the current working directory (useful for debugging)
print(f"Current Working Directory: {os.getcwd()}")

# Adjust the path to the 'python' folder inside the project structure
python_folder_path = os.path.abspath("../python")  # Adjust as needed

# Add the folder to sys.path if not already present
if python_folder_path not in sys.path:
    sys.path.insert(0, python_folder_path)  # Use insert(0) for priority

# Try importing the modules
try:
    from program2 import program2  # Importing program2
    from program5B import program5B  # Importing program5B
    print("Modules imported successfully.")
except ModuleNotFoundError as e:
    print(f"Error: {e}. Check if the files exist and the path is correct.")
# Out:
# Current Working Directory: c:\Users\odpol\Documents\GitHub\COP4533_Group_Project\notebooks
# Modules imported successfully.

# %%
import random

# Non-Increasing Heights
def generate_non_increasing_cases():
    cases = []
    max_platform_width = 10
    for _ in range(10):
        n = random.randint(5, 10)
        heights = sorted([random.randint(1, 10) for _ in range(n)], reverse=True)
        widths = [random.randint(1, max_platform_width) for _ in range(n)]
        case = (n, max_platform_width, heights, widths, "Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD")
        cases.append(case)
    return cases


# Strictly Increasing Heights
def generate_increasing_cases():
    cases = []
    max_platform_width = 10
    for _ in range(10):
        n = random.randint(5, 10)
        heights = sorted([random.randint(1, 10) for _ in range(n)])
        widths = [random.randint(1, max_platform_width) for _ in range(n)]
        case = (n, max_platform_width, heights, widths, "Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD")
        cases.append(case)
    return cases


# Unimodal Valley
def generate_unimodal_valley_cases():
    cases = []
    max_platform_width = 10
    for _ in range(10):
        n = random.randint(5, 10)
        peak = random.randint(1, 10)
        left = sorted([random.randint(1, peak) for _ in range(n // 2)], reverse=True)
        right = sorted([random.randint(1, peak) for _ in range(n - len(left))])
        heights = left + right
        widths = [random.randint(1, max_platform_width) for _ in range(n)]
        case = (n, max_platform_width, heights, widths, "Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD")
        cases.append(case)
    return cases


# Unimodal Peak
def generate_unimodal_peak_cases():
    cases = []
    max_platform_width = 10
    for _ in range(10):
        n = random.randint(5, 10)
        peak = random.randint(1, 10)
        left = sorted([random.randint(1, peak) for _ in range(n // 2)])
        right = sorted([random.randint(1, peak) for _ in range(n - len(left))], reverse=True)
        heights = left + right
        widths = [random.randint(1, max_platform_width) for _ in range(n)]
        case = (n, max_platform_width, heights, widths, "Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD")
        cases.append(case)
    return cases


# Completely Random Heights
def generate_random_cases():
    cases = []
    max_platform_width = 100
    for _ in range(10):
        n = random.randint(5, 10)
        heights = [random.randint(1, 100) for _ in range(n)]
        widths = [random.randint(1, max_platform_width) for _ in range(n)]
        case = (n, max_platform_width, heights, widths, "Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD")
        cases.append(case)
    return cases


# Random Heights (Range 1-25)
def generate_random_heights_cases():
    cases = []
    max_platform_width = 25
    for _ in range(10):
        n = random.randint(5, 10)
        heights = [random.randint(1, 25) for _ in range(n)]
        widths = [random.randint(1, max_platform_width) for _ in range(n)]
        case = (n, max_platform_width, heights, widths, "Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD")
        cases.append(case)
    return cases

# %%
# Collect all cases into one list
def collect_all_cases():
    all_cases = []
    
    # Add each scenario
    all_cases.extend(generate_non_increasing_cases())
    all_cases.extend(generate_increasing_cases())
    all_cases.extend(generate_unimodal_valley_cases())
    all_cases.extend(generate_unimodal_peak_cases())
    all_cases.extend(generate_random_cases())
    all_cases.extend(generate_random_heights_cases())
    
    return all_cases

# Generate all test cases
test_cases = collect_all_cases()

# Print the output in the requested format
print("test_cases = [")
for case in test_cases:
    print(f"    {case},")
print("]")
# Out:
# test_cases = [
#     (9, 10, [10, 10, 8, 6, 5, 5, 5, 3, 1], [7, 1, 2, 2, 6, 3, 2, 6, 8], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (9, 10, [10, 9, 7, 7, 7, 7, 6, 2, 1], [10, 4, 9, 3, 10, 7, 10, 8, 9], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (10, 10, [10, 10, 7, 7, 7, 7, 4, 3, 3, 1], [7, 4, 7, 6, 3, 7, 6, 10, 2, 4], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (9, 10, [9, 8, 7, 7, 5, 3, 3, 2, 2], [5, 4, 7, 10, 3, 5, 9, 4, 10], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (5, 10, [6, 5, 4, 2, 1], [3, 8, 9, 8, 9], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (5, 10, [10, 10, 5, 4, 2], [6, 9, 6, 1, 1], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (10, 10, [10, 10, 8, 8, 7, 7, 7, 6, 3, 2], [1, 1, 6, 10, 10, 5, 7, 5, 2, 8], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (6, 10, [9, 7, 4, 3, 2, 2], [8, 8, 10, 9, 5, 9], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (10, 10, [9, 8, 8, 7, 5, 5, 4, 3, 3, 1], [7, 6, 1, 8, 8, 5, 7, 5, 6, 10], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (8, 10, [8, 8, 7, 6, 6, 2, 2, 1], [1, 1, 9, 10, 3, 6, 6, 4], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (6, 10, [3, 6, 7, 7, 7, 10], [6, 5, 8, 9, 5, 9], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (5, 10, [1, 1, 5, 7, 8], [10, 2, 5, 6, 8], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (5, 10, [1, 1, 3, 5, 7], [7, 8, 5, 8, 4], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (10, 10, [1, 3, 4, 5, 8, 8, 9, 10, 10, 10], [6, 5, 9, 4, 6, 8, 9, 2, 1, 5], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (5, 10, [3, 3, 6, 7, 10], [8, 4, 3, 8, 9], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (6, 10, [2, 5, 6, 8, 8, 10], [10, 6, 3, 2, 8, 3], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (7, 10, [4, 4, 7, 9, 9, 9, 10], [3, 2, 10, 3, 5, 9, 7], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (10, 10, [1, 1, 1, 1, 3, 3, 6, 6, 8, 9], [7, 9, 3, 2, 8, 9, 8, 3, 6, 7], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (10, 10, [2, 2, 2, 4, 4, 7, 8, 10, 10, 10], [8, 3, 10, 9, 4, 9, 6, 4, 1, 6], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (10, 10, [1, 2, 2, 3, 3, 3, 6, 6, 7, 8], [10, 8, 1, 9, 6, 10, 2, 3, 2, 1], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (10, 10, [10, 10, 7, 5, 3, 1, 2, 3, 3, 4], [3, 7, 10, 2, 9, 2, 8, 2, 7, 2], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (7, 10, [3, 2, 2, 1, 1, 2, 4], [8, 3, 2, 3, 8, 4, 4], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (6, 10, [5, 4, 2, 1, 4, 5], [3, 2, 9, 2, 6, 8], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (5, 10, [5, 1, 2, 6, 7], [1, 9, 2, 7, 8], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (9, 10, [3, 2, 2, 1, 3, 4, 5, 5, 5], [9, 4, 4, 9, 5, 3, 3, 5, 10], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (8, 10, [1, 1, 1, 1, 1, 1, 1, 1], [5, 4, 8, 5, 6, 4, 9, 6], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (8, 10, [1, 1, 1, 1, 1, 1, 1, 1], [2, 7, 9, 8, 6, 3, 10, 3], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (6, 10, [1, 1, 1, 1, 1, 1], [5, 8, 5, 1, 10, 9], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (8, 10, [5, 5, 3, 3, 1, 1, 4, 5], [8, 2, 5, 1, 10, 5, 6, 9], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (9, 10, [2, 2, 2, 1, 1, 1, 1, 1, 2], [9, 9, 1, 6, 1, 3, 8, 5, 10], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (8, 10, [1, 1, 1, 2, 2, 2, 2, 1], [4, 4, 4, 4, 2, 5, 2, 5], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (5, 10, [1, 1, 1, 1, 1], [5, 7, 9, 5, 2], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (10, 10, [4, 6, 6, 7, 9, 9, 8, 8, 8, 6], [5, 3, 7, 5, 10, 2, 7, 5, 8, 3], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (7, 10, [2, 3, 7, 7, 5, 3, 3], [2, 3, 8, 9, 7, 1, 6], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (7, 10, [1, 3, 6, 7, 5, 2, 1], [10, 4, 6, 6, 8, 8, 1], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (5, 10, [5, 6, 2, 2, 1], [4, 7, 5, 5, 3], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (7, 10, [1, 1, 1, 1, 1, 1, 1], [7, 3, 9, 2, 4, 5, 7], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (10, 10, [1, 1, 1, 2, 3, 2, 2, 1, 1, 1], [3, 4, 5, 5, 4, 8, 8, 6, 9, 7], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (6, 10, [1, 2, 4, 6, 4, 3], [7, 7, 10, 5, 8, 3], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (5, 10, [1, 1, 4, 3, 3], [2, 5, 8, 4, 8], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (8, 100, [55, 90, 70, 27, 59, 3, 66, 37], [29, 81, 36, 52, 3, 78, 94, 82], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (5, 100, [98, 41, 37, 49, 42], [2, 89, 88, 36, 26], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (9, 100, [93, 45, 81, 82, 60, 5, 9, 80, 18], [33, 89, 26, 62, 93, 25, 43, 83, 35], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (9, 100, [74, 36, 5, 78, 2, 73, 73, 33, 96], [98, 8, 23, 23, 69, 86, 77, 65, 9], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (7, 100, [6, 68, 63, 7, 76, 62, 11], [39, 78, 86, 95, 91, 66, 80], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (7, 100, [97, 80, 37, 26, 67, 80, 78], [96, 3, 81, 26, 79, 9, 79], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (9, 100, [55, 97, 50, 18, 42, 62, 37, 18, 47], [61, 45, 88, 83, 52, 89, 63, 89, 28], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (5, 100, [96, 55, 74, 31, 100], [76, 59, 2, 97, 7], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (5, 100, [82, 22, 93, 24, 21], [23, 61, 39, 93, 65], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (10, 100, [30, 43, 21, 31, 34, 31, 53, 47, 75, 7], [17, 64, 39, 60, 66, 75, 29, 98, 70, 80], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (10, 25, [8, 23, 5, 13, 23, 6, 25, 15, 15, 20], [2, 7, 25, 11, 19, 10, 17, 15, 3, 4], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (8, 25, [9, 5, 17, 21, 19, 12, 11, 21], [8, 23, 19, 16, 14, 13, 12, 13], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (8, 25, [13, 23, 6, 7, 15, 3, 17, 2], [17, 10, 3, 19, 24, 4, 18, 16], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (10, 25, [21, 7, 17, 9, 23, 15, 25, 23, 8, 25], [24, 6, 2, 15, 11, 1, 22, 8, 11, 8], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (10, 25, [8, 9, 24, 6, 17, 16, 11, 15, 24, 11], [13, 4, 5, 8, 18, 2, 7, 21, 1, 11], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (5, 25, [5, 2, 1, 6, 14], [11, 16, 5, 20, 14], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (7, 25, [22, 9, 23, 13, 1, 6, 5], [8, 6, 13, 7, 12, 23, 25], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (8, 25, [5, 19, 12, 20, 5, 18, 12, 2], [25, 19, 4, 19, 1, 15, 19, 24], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (6, 25, [14, 10, 20, 3, 12, 8], [6, 24, 16, 5, 15, 6], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
#     (8, 25, [22, 17, 16, 10, 20, 19, 12, 11], [13, 12, 11, 21, 19, 14, 12, 9], 'Expected: TBD platforms, Total Height: TBD, Sculptures per Platform: TBD'),
# ]

# %%
import pandas as pd

# Update: Include sequence type
def collect_all_cases_with_types():
    all_cases = []
    all_cases.extend((case + ("Non-Increasing",) for case in generate_non_increasing_cases()))
    all_cases.extend((case + ("Increasing",) for case in generate_increasing_cases()))
    all_cases.extend((case + ("Unimodal Valley",) for case in generate_unimodal_valley_cases()))
    all_cases.extend((case + ("Unimodal Peak",) for case in generate_unimodal_peak_cases()))
    all_cases.extend((case + ("Random (1-100)",) for case in generate_random_cases()))
    all_cases.extend((case + ("Random (1-25)",) for case in generate_random_heights_cases()))
    return all_cases

test_cases = collect_all_cases_with_types()

def run_algorithms_and_tabulate(test_cases):
    """
    Runs Program2 (Greedy-Unimodal) and Program5B (Dynamic-Optimal) for all test cases and tabulates the results.
    """
    results = []  # To store the tabulated results

    for idx, (n, W, heights, widths, _, seq_type) in enumerate(test_cases):
        # Run Program2
        try:
            platforms_p2, height_p2, sculptures_p2 = program2(n, W, heights, widths)
        except Exception:
            platforms_p2, height_p2, sculptures_p2 = "Error", "Error", "Error"

        # Run Program5B
        try:
            platforms_p5b, height_p5b, sculptures_p5b = program5B(n, W, heights, widths)
        except Exception:
            platforms_p5b, height_p5b, sculptures_p5b = "Error", "Error", "Error"

        # Add results to the table
        results.append({
            "TestCase#": idx + 1,
            "Sequence Type": seq_type,
            "Input": f"n={n}, W={W}",
            "P2 Platforms": platforms_p2,
            "P5B Platforms": platforms_p5b,
            "P2 Height": height_p2,
            "P5B Height": height_p5b,
            "Cost Diff": "Yes" if (platforms_p2, height_p2) != (platforms_p5b, height_p5b) else "No",
        })

    # Convert results to a DataFrame
    df = pd.DataFrame(results)
    return df

# Generate and tabulate
df_results = run_algorithms_and_tabulate(test_cases)

# Ensure "Sequence Type" follows the desired order
desired_order = ["Non-Increasing", "Increasing", "Unimodal Valley", "Unimodal Peak", "Random (1-100)", "Random (1-25)"]
df_results["Sequence Type"] = pd.Categorical(df_results["Sequence Type"], categories=desired_order, ordered=True)

# Display configuration
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# Group and display
# Group and display
print("Results by Sequence Type:")
for seq_type, group in df_results.groupby("Sequence Type", observed=True):  # Explicitly set observed=True
    print(f"\nSequence Type: {seq_type}")
    print(group[["TestCase#", "Input", "P2 Platforms", "P5B Platforms", "P2 Height", "P5B Height", "Cost Diff"]])


# Optional: Save results to a CSV
df_results.to_csv("./csv_files/algorithm_comparison_results.csv", index=False)
# Out:
# Results by Sequence Type:
#
# Sequence Type: Non-Increasing
#    TestCase#       Input  P2 Platforms  P5B Platforms  P2 Height  P5B Height Cost Diff
# 0          1   n=8, W=10             4              4         16          16        No
# 1          2   n=8, W=10             6              6         39          39        No
# 2          3   n=9, W=10             7              7         39          39        No
# 3          4   n=6, W=10             4              4         14          14        No
# 4          5   n=8, W=10             4              4         22          22        No
# 5          6   n=5, W=10             3              3         18          18        No
# 6          7   n=7, W=10             6              6         30          30        No
# 7          8  n=10, W=10             6              6         31          31        No
# 8          9   n=5, W=10             5              5         22          22        No
# 9         10   n=6, W=10             5              5         28          28        No
#
# Sequence Type: Increasing
#     TestCase#       Input  P2 Platforms  P5B Platforms  P2 Height  P5B Height Cost Diff
# 10         11   n=6, W=10             4              4         20          20        No
# 11         12   n=8, W=10             5              5         26          26        No
# 12         13   n=6, W=10             4              4         14          14        No
# 13         14   n=5, W=10             4              4         26          26        No
# 14         15  n=10, W=10             7              7         42          42        No
# 15         16  n=10, W=10             8              8         47          47        No
# 16         17   n=9, W=10             6              6         39          39        No
# 17         18   n=6, W=10             5              5         30          30        No
# 18         19  n=10, W=10             7              7         36          36        No
# 19         20   n=9, W=10             4              4         28          28        No
#
# Sequence Type: Unimodal Valley
#     TestCase#      Input  P2 Platforms  P5B Platforms  P2 Height  P5B Height Cost Diff
# 20         21  n=5, W=10             3              3          5           5        No
# 21         22  n=7, W=10             7              7         28          28        No
# 22         23  n=8, W=10             6              6          9           9        No
# 23         24  n=9, W=10             3              3          7           7        No
# 24         25  n=8, W=10             6              6         26          26        No
# 25         26  n=9, W=10             5              5          6           6        No
# 26         27  n=6, W=10             5              5         22          22        No
# 27         28  n=5, W=10             4              4          6           6        No
# 28         29  n=8, W=10             7              7         11          11        No
# 29         30  n=9, W=10             8              8          8           8        No
#
# Sequence Type: Unimodal Peak
#     TestCase#       Input  P2 Platforms  P5B Platforms  P2 Height  P5B Height Cost Diff
# 30         31  n=10, W=10             7              7          7           7        No
# 31         32   n=7, W=10             6              6          6           6        No
# 32         33   n=9, W=10             6              6          6           6        No
# 33         34  n=10, W=10             7              7         25          25        No
# 34         35   n=7, W=10             6              6         39          39        No
# 35         36   n=8, W=10             5              5          5           5        No
# 36         37   n=7, W=10             5              5          8           8        No
# 37         38   n=6, W=10             3              3         18          17       Yes
# 38         39   n=7, W=10             4              4         14          12       Yes
# 39         40   n=5, W=10             4              4          8           7       Yes
#
# Sequence Type: Random (1-100)
#     TestCase#       Input  P2 Platforms  P5B Platforms  P2 Height  P5B Height Cost Diff
# 40         41  n=7, W=100             4              4        217         218       Yes
# 41         42  n=8, W=100             6              6        296         296        No
# 42         43  n=5, W=100             2              2        128         128        No
# 43         44  n=9, W=100             6              6        352         341       Yes
# 44         45  n=7, W=100             5              5        237         237        No
# 45         46  n=6, W=100             6              6        391         391        No
# 46         47  n=7, W=100             5              5        320         320        No
# 47         48  n=6, W=100             6              6        344         344        No
# 48         49  n=7, W=100             4              4        277         277        No
# 49         50  n=6, W=100             5              5        255         255        No
#
# Sequence Type: Random (1-25)
#     TestCase#       Input  P2 Platforms  P5B Platforms  P2 Height  P5B Height Cost Diff
# 50         51   n=8, W=25             5              5         88          88        No
# 51         52   n=8, W=25             7              7         88          88        No
# 52         53  n=10, W=25             7              7         77          77        No
# 53         54   n=5, W=25             2              2         44          44        No
# 54         55   n=6, W=25             5              5         50          50        No
# 55         56   n=5, W=25             3              3         30          30        No
# 56         57   n=8, W=25             7              7         87          87        No
# 57         58   n=6, W=25             3              3         58          58        No
# 58         59   n=9, W=25             3              3         52          52        No
# 59         60   n=9, W=25             7              7        102         102        No
