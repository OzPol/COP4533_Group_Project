# %%
import sys
import os

# Check the current working directory (useful for debugging)
print(f"Current Working Directory: {os.getcwd()}")

# Adjust the path to the 'python' folder inside the project structure
python_folder_path = os.path.abspath("../python")  # Adjust as needed

# Add the folder to sys.path if not already present
if python_folder_path not in sys.path:
    sys.path.insert(0, python_folder_path)  # Use insert(0) for priority

# Try importing the modules
try:
    from program1 import program1  # Importing program1
    from program2 import program2  # Importing program2
    print("Modules imported successfully.")
except ModuleNotFoundError as e:
    print(f"Error: {e}. Check if the files exist and the path is correct.")
# Out:
# Current Working Directory: c:\Users\odpol\Documents\GitHub\COP4533_Group_Project\notebooks
# Modules imported successfully.

# %%
# Milestone1 Program1 
def run_milestone1_prog1_tests():
    test_cases = [
        # Test Case 1
        (7, 10, [21, 19, 17, 16, 11, 5, 1], [7, 1, 2, 3, 5, 8, 1], 
        "Expected: 3 platforms, Total Height: 42, Sculptures per Platform: [3, 2, 2]"),
        
        # Test Case 2
        (4, 10, [8, 10, 9, 7], [8, 1, 2, 2], 
        "Expected: Error heights must be non-increasing."),
        
        # Test Case 3
        (7, 10, [12, 10, 9, 7, 8, 10, 11], [3, 2, 3, 4, 3, 2, 3], 
        "Expected: Error heights must be non-increasing."),
        
        # Test Case 4
        (1, 5, [5], [3], 
        "Expected: 1 platform, Total Height: 5, Sculptures per Platform: [1]"),
        
        # Test Case 5
        (5, 10, [10, 20, 15, 30, 25], [2, 2, 2, 2, 2], 
        "Expected: Error heights must be non-increasing."),
        
        # Test Case 6 
        (5, 10, [15, 15, 10, 10, 5], [2, 2, 2, 2, 2], 
        "Expected: 1 platform, Total Height: 15, Sculptures per Platform: [5]"),
        
        # Test Case 7
        (6, 10, [35, 15, 15, 10, 10, 5], [1, 2, 3, 4, 5, 6], 
        "Expected: 3 platform, Total Height: 50, Sculptures per Platform: [4, 1, 1]"),
        
        # Test Case 28
        (0, 0, [0], [0], 
        "Expected: 0 platform, Total Height: 0, Sculptures per Platform: [0]"),
    
    ]

    for i, (n, W, heights, widths, description) in enumerate(test_cases):
        print(f"Running Test Case {i + 1}: \n{description}")
        try:
            platforms, total_height, sculptures_per_platform = program1(n, W, heights, widths)
            print(f"Result: {platforms} platforms, Total Height: {total_height}, Sculptures per Platform: {sculptures_per_platform}\n")
        except ValueError as e:
            print(f"Result: Error: {e}\n")  # Print the error but continue with other test cases


# Run the tests for Milestone 1
run_milestone1_prog1_tests()
# Out:
# Running Test Case 1:
# Expected: 3 platforms, Total Height: 42, Sculptures per Platform: [3, 2, 2]
# Result: 3 platforms, Total Height: 42, Sculptures per Platform: [3, 2, 2]
#
# Running Test Case 2:
# Expected: Error heights must be non-increasing.
# Result: Error: Heights must be in non-increasing order for ProblemS1.
#
# Running Test Case 3:
# Expected: Error heights must be non-increasing.
# Result: Error: Heights must be in non-increasing order for ProblemS1.
#
# Running Test Case 4:
# Expected: 1 platform, Total Height: 5, Sculptures per Platform: [1]
# Result: 1 platforms, Total Height: 5, Sculptures per Platform: [1]
#
# Running Test Case 5:
# Expected: Error heights must be non-increasing.
# Result: Error: Heights must be in non-increasing order for ProblemS1.
#
# Running Test Case 6:
# Expected: 1 platform, Total Height: 15, Sculptures per Platform: [5]
# Result: 1 platforms, Total Height: 15, Sculptures per Platform: [5]
#
# Running Test Case 7:
# Expected: 3 platform, Total Height: 50, Sculptures per Platform: [4, 1, 1]
# Result: 3 platforms, Total Height: 50, Sculptures per Platform: [4, 1, 1]
#
# Running Test Case 8:
# Expected: 0 platform, Total Height: 0, Sculptures per Platform: [0]
# Result: Error: The number of heights and widths must match the number of sculptures.

# %%
# Milestone1 Program2
def run_milestone1_prog2_tests():
    test_cases = [
        # Test Case 1
        (7, 10, [21, 19, 17, 16, 11, 5, 1], [7, 1, 2, 3, 5, 8, 1], 
        "Expected: 3 platforms, Total Height: 42, Sculptures per Platform: [3, 2, 2]"),
        #"Expected: Error: Heights must be unimodal (increase to a peak and then decrease)."),
        
        # Test Case 2 (this now has a unimodal structure)
        (5, 10, [15, 10, 5, 10, 15], [2, 2, 2, 2, 2], 
        "Expected: 1 platform, Total Height: 15, Sculptures per Platform: [5]"),
        
        # Test Case 3
        (7, 10, [12, 10, 9, 7, 8, 10, 11], [3, 2, 3, 4, 3, 2, 3], 
        "Expected: 3 platforms, Total Height: 30, Sculptures per Platform: [3, 1, 3]"),
        
        # Test Case 4
        (1, 5, [5], [3], 
        "Expected: 1 platform, Total Height: 5, Sculptures per Platform: [1]"),
        
        # Test Case 5
        (4, 10, [10, 9, 8, 7], [8, 1, 2, 2], 
        "Expected: 2 platforms, Total Height: 18, Sculptures per Platform: [2, 2] "),
        # "Expected: Error heights must be unimodal."),
        
        # Test Case 6 
        (5, 10, [15, 15, 10, 5, 10], [2, 2, 2, 2, 2], 
        "Expected: 1 platform, Total Height: 15, Sculptures per Platform: [5]"),
        
        # Test Case 7
        (6, 10, [35, 15, 15, 5, 10, 10], [1, 2, 3, 4, 5, 6], 
        "Expected: 3 platform, Total Height: 55, Sculptures per Platform: [4, 1, 1]"),
        
        # Test Case 8
        (6, 10, [35, 15, 15, 5, 10, 10], [1, 2, 3, 4, 5, 5], 
        "Expected: 2 platform, Total Height: 45, Sculptures per Platform: [4, 2]"),
        
        # Test Case 9   Width4, Height10 object fits with the Valley, but not optimal, so it should be placed on the 3rd platform
        (6, 10, [35, 15, 15, 5, 10, 10], [1, 2, 3, 5, 4, 6], 
        "Expected: 3 platform, Total Height: 50, Sculptures per Platform: [3, 1, 2]"),
        
        # Test Case 10 - The valley Doesn't fit with Left of the Valley, but should fit on the right side
        (5, 10, [35, 15, 15, 5, 10], [1, 2, 3, 5, 4], 
        "Expected: 2 platform, Total Height: 45, Sculptures per Platform: [3, 2]"),
        
        # Test Case 11
        (6, 10, [35, 15, 15, 5, 10, 10], [1, 2, 3, 5, 4, 7], 
        "Expected: 3 platform, Total Height: 55, Sculptures per Platform: [3, 2, 1]"),
        
        # Test Case 12
        (5, 10, [35, 15, 15, 5, 10], [4, 3, 2, 1, 1], 
        "Expected: 2 platform, Total Height: 45, Sculptures per Platform: [4, 1]"),
        
        # Test Case 13
        (6, 10, [35, 15, 10, 5, 15, 20], [3, 3, 2, 1, 1, 1], # [5,1] or [4,2] are valid
        "Expected: 2 platform, Total Height: 55, Sculptures per Platform: [5, 1]"),
        
        # Test Case 14
        (6, 10, [35, 15, 10, 5, 10, 15], [3, 3, 2, 1, 1, 10], 
        "Expected: 2 platform, Total Height: 50, Sculptures per Platform: [5, 1]"), 
        
        # Test Case 15  # [4, 2] , [1, 5] are both valid
        (6, 10, [35, 15, 10, 5, 75, 85], [3, 3, 2, 1, 1, 1], 
        "Expected: 2 platform, Total Height: 120, Sculptures per Platform: [1, 5]"),
        
        # Test Case 16  
        (6, 10, [35, 15, 10, 5, 75, 85], [3, 3, 2, 2, 5, 5], 
        "Expected: 2 platform, Total Height: 120, Sculptures per Platform: [4, 2]"),
        
        # Test Case 17
        (6, 10, [35, 15, 10, 5, 75, 85], [3, 3, 2, 1, 4, 5], 
        "Expected: 2 platform, Total Height: 120, Sculptures per Platform: [3, 3]"),
        
        # Test Case 18
        (6, 10, [35, 15, 10, 5, 75, 85], [3, 3, 2, 1, 4, 10], 
        "Expected: 3 platform, Total Height: 195, Sculptures per Platform: [1, 4, 1]"),
        
        # Test Case 19
        (6, 10, [35, 15, 10, 5, 75, 85], [3, 3, 5, 1, 4, 10], 
        "Expected: 3 platform, Total Height: 195, Sculptures per Platform: [2, 3, 1]"),
        
    ]

    for i, (n, W, heights, widths, description) in enumerate(test_cases):
        print(f"Running Test Case {i + 1}: \n{description}")
        try:
            platforms, total_height, sculptures_per_platform = program2(n, W, heights, widths)
            print(f"Result: {platforms} platforms, Total Height: {total_height}, Sculptures per Platform: {sculptures_per_platform}\n")
        except ValueError as e:
            print(f"Result: Error: {e}\n")  # Print the error but continue with other test cases

# Run the tests for Milestone 1
run_milestone1_prog2_tests()
# Out:
# Running Test Case 1:
# Expected: 3 platforms, Total Height: 42, Sculptures per Platform: [3, 2, 2]
# Result: 3 platforms, Total Height: 42, Sculptures per Platform: [3, 2, 2]
#
# Running Test Case 2:
# Expected: 1 platform, Total Height: 15, Sculptures per Platform: [5]
# Result: 1 platforms, Total Height: 15, Sculptures per Platform: [5]
#
# Running Test Case 3:
# Expected: 3 platforms, Total Height: 30, Sculptures per Platform: [3, 1, 3]
# Result: 3 platforms, Total Height: 30, Sculptures per Platform: [3, 1, 3]
#
# Running Test Case 4:
# Expected: 1 platform, Total Height: 5, Sculptures per Platform: [1]
# Result: 1 platforms, Total Height: 5, Sculptures per Platform: [1]
#
# Running Test Case 5:
# Expected: 2 platforms, Total Height: 18, Sculptures per Platform: [2, 2]
# Result: 2 platforms, Total Height: 18, Sculptures per Platform: [2, 2]
#
# Running Test Case 6:
# Expected: 1 platform, Total Height: 15, Sculptures per Platform: [5]
# Result: 1 platforms, Total Height: 15, Sculptures per Platform: [5]
#
# Running Test Case 7:
# Expected: 3 platform, Total Height: 55, Sculptures per Platform: [4, 1, 1]
# Result: 3 platforms, Total Height: 55, Sculptures per Platform: [4, 1, 1]
#
# Running Test Case 8:
# Expected: 2 platform, Total Height: 45, Sculptures per Platform: [4, 2]
# Result: 2 platforms, Total Height: 45, Sculptures per Platform: [4, 2]
#
# Running Test Case 9:
# Expected: 3 platform, Total Height: 50, Sculptures per Platform: [3, 1, 2]
# Result: 3 platforms, Total Height: 50, Sculptures per Platform: [3, 1, 2]
#
# Running Test Case 10:
# Expected: 2 platform, Total Height: 45, Sculptures per Platform: [3, 2]
# Result: 2 platforms, Total Height: 45, Sculptures per Platform: [3, 2]
#
# Running Test Case 11:
# Expected: 3 platform, Total Height: 55, Sculptures per Platform: [3, 2, 1]
# Result: 3 platforms, Total Height: 55, Sculptures per Platform: [3, 2, 1]
#
# Running Test Case 12:
# Expected: 2 platform, Total Height: 45, Sculptures per Platform: [4, 1]
# Result: 2 platforms, Total Height: 45, Sculptures per Platform: [4, 1]
#
# Running Test Case 13:
# Expected: 2 platform, Total Height: 55, Sculptures per Platform: [5, 1]
# Result: 2 platforms, Total Height: 55, Sculptures per Platform: [5, 1]
#
# Running Test Case 14:
# Expected: 2 platform, Total Height: 50, Sculptures per Platform: [5, 1]
# Result: 2 platforms, Total Height: 50, Sculptures per Platform: [5, 1]
#
# Running Test Case 15:
# Expected: 2 platform, Total Height: 120, Sculptures per Platform: [1, 5]
# Result: 2 platforms, Total Height: 120, Sculptures per Platform: [1, 5]
#
# Running Test Case 16:
# Expected: 2 platform, Total Height: 120, Sculptures per Platform: [4, 2]
# Result: 2 platforms, Total Height: 120, Sculptures per Platform: [4, 2]
#
# Running Test Case 17:
# Expected: 2 platform, Total Height: 120, Sculptures per Platform: [3, 3]
# Result: 2 platforms, Total Height: 120, Sculptures per Platform: [3, 3]
#
# Running Test Case 18:
# Expected: 3 platform, Total Height: 195, Sculptures per Platform: [1, 4, 1]
# Result: 3 platforms, Total Height: 195, Sculptures per Platform: [1, 4, 1]
#
# Running Test Case 19:
# Expected: 3 platform, Total Height: 195, Sculptures per Platform: [2, 3, 1]
# Result: 3 platforms, Total Height: 195, Sculptures per Platform: [2, 3, 1]

# %%
# Milestone 2

def run_milestone2_tests():
    test_cases = [
        (7, 10, [21, 19, 17, 16, 11, 5, 1], [7, 1, 2, 3, 5, 8, 1], 
        "Expected: 3 platforms, Total Height: 42, Sculptures per Platform: [3, 2, 2]"),
        
        (4, 10, [8, 10, 9, 7], [8, 1, 2, 2], "Expected: 2 platforms, Total Height: 18"),
        (7, 10, [12, 10, 9, 7, 8, 10, 11], [3, 2, 3, 4, 3, 2, 3], "Expected: 3 platforms, Total Height: 30"),
        (1, 5, [5], [3], "Expected: 1 platform, Total Height: 5"),
        (5, 10, [10, 20, 15, 30, 25], [2, 2, 2, 2, 2], "Expected: 1 platform, Total Height: 30")
    ]

    for i, (n, W, heights, widths, description) in enumerate(test_cases):
        print(f"Running Test Case {i+1}: \n{description}")
        platforms, total_height, sculptures_per_platform = program2(n, W, heights, widths)
        print(f"Result: {platforms} platforms, Total Height: {total_height}, Sculptures per Platform: {sculptures_per_platform}\n")

# Run the tests for Milestone 2
run_milestone2_tests()
# Out:
# Running Test Case 1:
# Expected: 3 platforms, Total Height: 42, Sculptures per Platform: [3, 2, 2]
# Result: 3 platforms, Total Height: 42, Sculptures per Platform: [3, 2, 2]
#
# Running Test Case 2:
# Expected: 2 platforms, Total Height: 18
# Result: 2 platforms, Total Height: 17, Sculptures per Platform: [2, 2]
#
# Running Test Case 3:
# Expected: 3 platforms, Total Height: 30
# Result: 3 platforms, Total Height: 30, Sculptures per Platform: [3, 1, 3]
#
# Running Test Case 4:
# Expected: 1 platform, Total Height: 5
# Result: 1 platforms, Total Height: 5, Sculptures per Platform: [1]
#
# Running Test Case 5:
# Expected: 1 platform, Total Height: 30
# Result: 1 platforms, Total Height: 30, Sculptures per Platform: [5]

# %%
# Milestone 3
def run_milestone3_tests():
    test_cases = [
        (7, 10, [21, 19, 17, 16, 11, 5, 1], [7, 1, 2, 3, 5, 8, 1], "Expected: 3 platforms, Total Height: 42"),
        (4, 10, [8, 10, 9, 7], [8, 1, 2, 2], "Expected: 2 platforms, Total Height: 18"),
        (7, 10, [12, 10, 9, 7, 8, 10, 11], [3, 2, 3, 4, 3, 2, 3], "Expected: 3 platforms, Total Height: 30"),
        (1, 5, [5], [3], "Expected: 1 platform, Total Height: 5"),
        (5, 10, [10, 20, 15, 30, 25], [2, 2, 2, 2, 2], "Expected: 1 platform, Total Height: 30")
    ]

    for i, (n, W, heights, widths, description) in enumerate(test_cases):
        print(f"Running Test Case {i+1}: {description}")
        platforms, total_height, sculptures_per_platform = program2(n, W, heights, widths)
        print(f"Result: Platforms: {platforms}, Total Height: {total_height}, Sculptures per Platform: {sculptures_per_platform}\n")

# Run the tests for Milestone 3
run_milestone3_tests()
# Out:
# Running Test Case 1: Expected: 3 platforms, Total Height: 42
# Result: Platforms: 3, Total Height: 42, Sculptures per Platform: [3, 2, 2]
#
# Running Test Case 2: Expected: 2 platforms, Total Height: 18
# Result: Platforms: 2, Total Height: 17, Sculptures per Platform: [2, 2]
#
# Running Test Case 3: Expected: 3 platforms, Total Height: 30
# Result: Platforms: 3, Total Height: 30, Sculptures per Platform: [3, 1, 3]
#
# Running Test Case 4: Expected: 1 platform, Total Height: 5
# Result: Platforms: 1, Total Height: 5, Sculptures per Platform: [1]
#
# Running Test Case 5: Expected: 1 platform, Total Height: 30
# Result: Platforms: 1, Total Height: 30, Sculptures per Platform: [5]

# %% [markdown]
# Milestone 1 - Test Case Code (C++)

# %% [markdown]
#     void run_milestone1_tests() {
#         vector<tuple<int, int, vector<int>, vector<int>, string>> test_cases = {
#             {7, 10, {21, 19, 17, 16, 11, 5, 1}, {7, 1, 2, 3, 5, 8, 1}, "Expected: 3 platforms, Total Height: 42"},
#             {4, 10, {8, 10, 9, 7}, {8, 1, 2, 2}, "Expected: 2 platforms, Total Height: 18"},
#             {7, 10, {12, 10, 9, 7, 8, 10, 11}, {3, 2, 3, 4, 3, 2, 3}, "Expected: 3 platforms, Total Height: 30"},
#             {1, 5, {5}, {3}, "Expected: 1 platform, Total Height: 5"},
#             {5, 10, {10, 20, 15, 30, 25}, {2, 2, 2, 2, 2}, "Expected: 1 platform, Total Height: 30"}
#         };
#
#         for (size_t i = 0; i < test_cases.size(); ++i) {
#             auto [n, W, heights, widths, description] = test_cases[i];
#             cout << "Running Test Case " << i + 1 << ": " << description << endl;
#             auto [platforms, total_height, sculptures_per_platform] = program1(n, W, heights, widths);
#             cout << "Result: Platforms: " << platforms << ", Total Height: " << total_height << ", Sculptures per Platform: ";
#             for (int sculptures : sculptures_per_platform) {
#                 cout << sculptures << " ";
#             }
#             cout << endl << endl;
#         }
#     }
#
#     int main() {
#         run_milestone1_tests();
#         return 0;
#     }

# %% [markdown]
# Milestone 2 - Test Case Code (C++)

# %% [markdown]
#     void run_milestone2_tests() {
#         vector<tuple<int, int, vector<int>, vector<int>, string>> test_cases = {
#             {7, 10, {21, 19, 17, 16, 11, 5, 1}, {7, 1, 2, 3, 5, 8, 1}, "Expected: 3 platforms, Total Height: 42"},
#             {4, 10, {8, 10, 9, 7}, {8, 1, 2, 2}, "Expected: 2 platforms, Total Height: 18"},
#             {7, 10, {12, 10, 9, 7, 8, 10, 11}, {3, 2, 3, 4, 3, 2, 3}, "Expected: 3 platforms, Total Height: 30"},
#             {1, 5, {5}, {3}, "Expected: 1 platform, Total Height: 5"},
#             {5, 10, {10, 20, 15, 30, 25}, {2, 2, 2, 2, 2}, "Expected: 1 platform, Total Height: 30"}
#         };
#
#         for (size_t i = 0; i < test_cases.size(); ++i) {
#             auto [n, W, heights, widths, description] = test_cases[i];
#             cout << "Running Test Case " << i + 1 << ": " << description << endl;
#             auto [platforms, total_height, sculptures_per_platform] = program2(n, W, heights, widths);
#             cout << "Result: Platforms: " << platforms << ", Total Height: " << total_height << ", Sculptures per Platform: ";
#             for (int sculptures : sculptures_per_platform) {
#                 cout << sculptures << " ";
#             }
#             cout << endl << endl;
#         }
#     }
#
#     int main() {
#         run_milestone2_tests();
#         return 0;
#     }

# %% [markdown]
# Milestone 3 - Test Case Code (C++)

# %% [markdown]
#     void run_milestone3_tests() {
#         vector<tuple<int, int, vector<int>, vector<int>, string>> test_cases = {
#             {7, 10, {21, 19, 17, 16, 11, 5, 1}, {7, 1, 2, 3, 5, 8, 1}, "Expected: 3 platforms, Total Height: 42"},
#             {4, 10, {8, 10, 9, 7}, {8, 1, 2, 2}, "Expected: 2 platforms, Total Height: 18"},
#             {7, 10, {12, 10, 9, 7, 8, 10, 11}, {3, 2, 3, 4, 3, 2, 3}, "Expected: 3 platforms, Total Height: 30"},
#             {1, 5, {5}, {3}, "Expected: 1 platform, Total Height: 5"},
#             {5, 10, {10, 20, 15, 30, 25}, {2, 2, 2, 2, 2}, "Expected: 1 platform, Total Height: 30"}
#         };
#
#         for (size_t i = 0; i < test_cases.size(); ++i) {
#             auto [n, W, heights, widths, description] = test_cases[i];
#             cout << "Running Test Case " << i + 1 << ": " << description << endl;
#             auto [platforms, total_height, sculptures_per_platform] = program3(n, W, heights, widths);
#             cout << "Result: Platforms: " << platforms << ", Total Height: " << total_height << ", Sculptures per Platform: ";
#             for (int sculptures : sculptures_per_platform) {
#                 cout << sculptures << " ";
#             }
#             cout << endl << endl;
#         }
#     }
#
#     int main() {
#         run_milestone3_tests();
#         return 0;
#     }
